# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Let's-start!" data-toc-modified-id="Let's-start!-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Let's start!</a></span></li><li><span><a href="#Basic-Data-Types:-Numbers,-Booleans,-and-Strings" data-toc-modified-id="Basic-Data-Types:-Numbers,-Booleans,-and-Strings-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Basic Data Types: Numbers, Booleans, and Strings</a></span><ul class="toc-item"><li><span><a href="#Numeric" data-toc-modified-id="Numeric-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Numeric</a></span><ul class="toc-item"><li><span><a href="#Mathematical-Operators:-+,--,-*,-/,-**" data-toc-modified-id="Mathematical-Operators:-+,--,-*,-/,-**-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Mathematical Operators: +, -, *, /, **</a></span></li><li><span><a href="#Shorthand-mathematical-operators" data-toc-modified-id="Shorthand-mathematical-operators-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Shorthand mathematical operators</a></span></li></ul></li><li><span><a href="#Booleans-&amp;-Logic-Operators" data-toc-modified-id="Booleans-&amp;-Logic-Operators-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Booleans &amp; Logic Operators</a></span><ul class="toc-item"><li><span><a href="#Logical-operators" data-toc-modified-id="Logical-operators-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Logical operators</a></span></li></ul></li><li><span><a href="#1.3-Strings" data-toc-modified-id="1.3-Strings-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>1.3 Strings</a></span><ul class="toc-item"><li><span><a href="#String-methods" data-toc-modified-id="String-methods-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>String methods</a></span></li></ul></li></ul></li><li><span><a href="#Container-Data-Types" data-toc-modified-id="Container-Data-Types-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Container Data Types</a></span><ul class="toc-item"><li><span><a href="#Lists" data-toc-modified-id="Lists-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Lists</a></span></li><li><span><a href="#Tuples" data-toc-modified-id="Tuples-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Tuples</a></span></li><li><span><a href="#Dictionaries" data-toc-modified-id="Dictionaries-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Dictionaries</a></span></li><li><span><a href="#Sets" data-toc-modified-id="Sets-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Sets</a></span></li></ul></li><li><span><a href="#3.-Functions" data-toc-modified-id="3.-Functions-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>3. Functions</a></span></li><li><span><a href="#Control-Flow" data-toc-modified-id="Control-Flow-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Control Flow</a></span><ul class="toc-item"><li><span><a href="#If/Else" data-toc-modified-id="If/Else-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>If/Else</a></span></li><li><span><a href="#Loops" data-toc-modified-id="Loops-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Loops</a></span><ul class="toc-item"><li><span><a href="#'while'-loops" data-toc-modified-id="'while'-loops-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>'while' loops</a></span></li><li><span><a href="#'for'-loops" data-toc-modified-id="'for'-loops-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>'for' loops</a></span></li><li><span><a href="#List/dict-comprehension" data-toc-modified-id="List/dict-comprehension-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>List/dict comprehension</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# Please note that we are using Python 3.7
# (__NOT__ Python 2! Python 2 is dead)

# %%
# Let's make sure we are using Python 3
import sys
print(sys.version)
# Out:
# 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]

# %% [markdown]
# # Let's start!

# %%
print('Hello AiSaturdays!')
# Out:
# Hello AiSaturdays!

# %% [markdown]
# `print` is a built-in function. We will use it several times.

# %% [markdown]
# # Basic Data Types: Numbers, Booleans, and Strings
#
# Basic data types in python3 are:
# https://realpython.com/python-data-types/
#
# - Numeric: Integers, float and complex numbers
# - Text: Strings
# - Logic: Boolean

# %% [markdown]
# ## Numeric
#
# Note:
# - Use the `type()` function to get the type of a variable
# - Numbers can be integers ('int'), such as 3, 5 and 3049
# - Decimal numbers are floats ('float'), such as 2.5, 3.1, and 2.34938493
# - Imaginary numbers are defined by the letter `j`

# %%
a_int = 5
print(type(a_int))
print(a_int)

a_float = 2.3
print(type(a_float))
print(a_float)

a_img = 2j
print(type(a_img))
print(a_img)
# Out:
# <class 'int'>
# 5
# <class 'float'>
# 2.3
# <class 'complex'>
# 2j

# %% [markdown]
# ### Mathematical Operators: +, -, \*, /, **
# Mathematical operators allow you to perform math operations.
#
# Note: ** is the exponentiation operator

# %%
a = 2
b = a + 1
print(b)
c = a - 1
print(c)
d = a * 2
print(d)
e = a / 2
print(e)

f = a ** 2
print(f)
# Out:
# 3
# 1
# 4
# 1.0
# 4

# %% [markdown]
# ### Shorthand mathematical operators
# `a += 1` is shorthand for `a = a + 1`

# %%
a = 5
a += 1
print(a)
a *= 2
print(a)
a /= 4
print(a)
a -= 2
print(a)
# Out:
# 6
# 12
# 3.0
# 1.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Warning :</b> `+=` it's not the same as `=+`.
# </div>

# %%
print(f'{a}')
# Out:
# 1.0

# %%
a = 1
a += 4
print(a)
# Out:
# 5

# %%
a = 1
a =+ 4
print(a)
# Out:
# 4

# %% [markdown]
# ## Booleans & Logic Operators

# %%
im_true = True
im_false = False

print(type(im_true))
print(im_true)
# Out:
# <class 'bool'>
# True

# %% [markdown]
# ### Logical operators
# Logical operators (`==` and `!=`) allow you to compare the values of variables on the left and right hand side.

# %%
print(im_true == im_false)
print(im_true != im_false)
# Out:
# False
# True

# %% [markdown]
# The `and` operator will return `True` only if both elements are `True`.

# %%
print(im_true and im_false)
# Out:
# False

# %% [markdown]
# The `or` operator will return `True` if  any of the variables are `True`.

# %%
print(im_true or im_false)
# Out:
# True

# %%
im_true + im_true
# Out:
# 2

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Warning :</b> Logical True often are treated like integer 1, and False as 0. Using math operations, eg `+`:
#     True+True wil be 2.
# </div>

# %%
True + True
# Out:
# 2

# %%
True and True
# Out:
# True

# %%
True + False
# Out:
# 1

# %%
True and False
# Out:
# False

# %% [markdown]
# ## 1.3 Strings
# You can use single or double quotes for strings.

# %% [markdown]
# my_string = 'Ai'
# my_other_string = "Saturdays"
# print(my_string, my_other_string)

# %% [markdown]
# ### String methods
# Concatenating strings:

# %%
another_string = 'Hello' + my_string + my_other_string
print(another_string)
# Out:
# HelloAiSaturdays

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Be aware of the spaces. </b>
# </div>

# %%
another_string = 'Hello, ' + my_string + " " + my_other_string
print(another_string)
# Out:
# hello, Ai Saturdays

# %% [markdown]
# Get the length of the string:

# %%
print(len(another_string))
# Out:
# 22

# %% [markdown]
# `len`is another built-in function

# %% [markdown]
# Strings can be multiplied.

# %% [markdown]
# # Container Data Types
#
# Some built-in containers are
# - List and Tuples
# - Set
# - Dict
#
# They can be divided in mutable or immutable:
#
# - Immutables: Tuples
# - Mutable: list, dict and sets.
#
#
# ## Lists
# A Python `list` stores multiple elements, which types can be different.

# %%
my_list = ['a', 'b', 'c', 3485]
print(my_list)
# Out:
# ['a', 'b', 'c', 3485]

# %% [markdown]
# You can access an element in a list with the following syntax:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note :</b> the first element in a list has an index of zero.
# </div>

# %%
print(my_list[2])
print(my_list[0])
# Out:
# c
# a

# %% [markdown]
# Reassigning elements in a list:

# %%
my_list[0] = 'Ai'
print(my_list)
# Out:
# ['Ai', 'b', 'c', 3485]

# %% [markdown]
# Adding/removing elements from a list:

# %%
my_list.append('Saturdays')
print(my_list)

my_list.pop()
print(my_list)
# Out:
# ['Ai', 'b', 'c', 3485, 'Saturdays']
# ['Ai', 'b', 'c', 3485]

# %% [markdown]
# Accessing multiple elements in a list:

# %%
print(my_list[0:2]) # Access elements in index 0, 1 and 2
print(my_list[2:]) # Access elements from index 2 to the end
print(my_list[:2]) # Access elements from the beginning to index 2
# Out:
# ['delta', 'b']
# ['c', 3485]
# ['delta', 'b']

# %% [markdown]
# ## Tuples
# A tuple is a sequence of immutable Python objects. Tuples are sequences, just like lists. The differences between tuples and lists are, the tuples cannot be changed unlike lists and tuples use parentheses, whereas lists use square brackets.

# %%
a = (2, 'a')
print(a)

print(a[0])
print(type(a))
# Out:
# (2, 'a')
# 2
# <class 'tuple'>

# %% [markdown]
# To access all properties and methods of an object, use the built-in function `dir`.

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %% [markdown]
# ## Dictionaries
# Dictionaries hold key/value pairs and are useful for storing information.

# %%
my_dict = { 'key_one': 'Ai', 'key_two': 'Saturdays' }
my_dict
# Out:
# {'key_one': 'Ai', 'key_two': 'Saturdays'}

# %% [markdown]
# Access a value from a dictionary by a key:

# %%
print(my_dict['key_one'])
print(my_dict['key_two'])
# Out:
# Ai
# Saturdays

# %% [markdown]
# Looping over values of a dictionary:
#
# <div class="alert alert-block alert-info">
# <b>Note :</b>  check next sections below for info about loops.
# </div>

# %%
for key in my_dict:
    print("The key is " + key)
# Out:
# The key is key_one
# The key is key_two

# %%
for key, value in my_dict.items():
    print("The key is " + key + ", and the value is " + value)
# Out:
# The key is key_one, and the value is Ai
# The key is key_two, and the value is Saturdays

# %% [markdown]
# ## Sets
# Sets are similar to lists, but can only contain unique values.

# %%
my_set = {1, 2, 3, 3, 3, 3, 'hello'}
print(my_set)
# Out:
# {'hello', 1, 2, 3}

# %% [markdown]
# When defining a set with the same value present multiple times, only one element will be added to the set.

# %% [markdown]
# # 3. Functions
# A function is a block of reusable code that performs a certain action. Once you've defined a function, you can use it anywhere in your code!

# %% [markdown]
# Defining a function:

# %%
def am_i_happy(happiness_level):
    """ Function that prints if I'm happy or not."""
    
    if happiness_level >= 10:
        return "I'm very happy."
    elif happiness_level >= 5:
        return "I'm happy."
    else:
        return "I am not happy."

# %% [markdown]
# Calling a function:

# %%
print(am_i_happy(0))
# Out:
# I am not happy.

# %%
print(am_i_happy(5))
# Out:
# I'm happy.

# %% [markdown]
# # Control Flow
#
# There are several control flow sentences. The basics are:
#
# - If/else statement:
# - Loops
#     * For loops
#     * List comprehension
#     * While loops

# %% [markdown]
# ## If/Else

# %%
sleepy = True
hungry = False

if sleepy and hungry:
    print("Eat a snack and take a nap.")
elif sleepy and not hungry:
    print("Take a nap")
elif hungry and not sleepy:
    print("Eat a snack")
else:
    print("Go on with your day")
# Out:
# Take a nap

# %% [markdown]
# ## Loops
# Iterate over iterables objects, such as strings, arrays, range, list, tuples, sets, dicts.
#
# ### 'while' loops
#
# While loops run until a exit condition is reached.

# %%
counter = 0
while (counter < 10): # this is the exit condition
    print("You have counted to", counter)
    counter = counter + 1 # Increment the counter
    
print("You're finished counting.")
# Out:
# You have counted to 0
# You have counted to 1
# You have counted to 2
# You have counted to 3
# You have counted to 4
# You have counted to 5
# You have counted to 6
# You have counted to 7
# You have counted to 8
# You have counted to 9
# You're finished counting.

# %% [markdown]
# ### 'for' loops
# Loop over a list:

# %%
cool_animals = ['cat', 'dog', 'lion', 'bear']
for animal in cool_animals:
    print(animal + "s are cool")
# Out:
# cats are cool
# dogs are cool
# lions are cool
# bears are cool

# %% [markdown]
# Loop over a dict:

# %%
animal_sounds = {
    'dog': 'bark',
    'cat': 'meow',
    'pig': 'oink'
}

for animal, sound in animal_sounds.items():
    print("The " + animal + " says " + sound + "!")
# Out:
# The dog says bark!
# The cat says meow!
# The pig says oink!

# %% [markdown]
# ### List/dict comprehension
#
# Another sintax to use `for-loops` in python are called list comprehension. Are much
# more readable and widely used.
#
# This sintax returns a `list`.

# %%
cool_animals = ['cat', 'dog', 'lion', 'bear']
text = [animal + "s are cool" for animal in cool_animals]

# %%
print(text)
# Out:
# ['cats are cool', 'dogs are cool', 'lions are cool', 'bears are cool']

# %%
print('Applause')
# Out:
# Applause
